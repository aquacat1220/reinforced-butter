# %%
from CybORG import CybORG
from CybORG.Simulator.Scenarios import EnterpriseScenarioGenerator
from CybORG.Agents import SleepAgent, EnterpriseGreenAgent, FiniteStateRedAgent
from rich import print

# %%
steps = 200
sg = EnterpriseScenarioGenerator(
    blue_agent_class=SleepAgent,
    green_agent_class=EnterpriseGreenAgent,
    red_agent_class=FiniteStateRedAgent,
    steps=steps
)
cyborg = CybORG(scenario_generator=sg, seed=1234)

# %%
reset = cyborg.reset(agent='blue_agent_0')

# %%
print(reset.observation)
# Out:
# {
#     'success': <TernaryEnum.UNKNOWN: 2>,
#     'restricted_zone_a_subnet_router': {
#         'Interface': [
#             {
#                 'interface_name': 'eth0',
#                 'ip_address': IPv4Address('10.0.145.154'),
#                 'Subnet': IPv4Network('10.0.145.0/24')
#             }
#         ],
#         'Sessions': [
#             {
#                 'session_id': 0,
#                 'username': 'ubuntu',
#                 'timeout': 0,
#                 'PID': 8,
#                 'Type': <SessionType.VELOCIRAPTOR_SERVER: 8>,
#                 'agent': 'blue_agent_0'
#             }
#         ],
#         'Processes': [{'PID': 8, 'username': 'ubuntu'}],
#         'User Info': [{'username': 'root', 'Groups': [{'GID': 0}]}, {'username': 'user', 'Groups': [{'GID': 1}]}],
#         'System info': {
#             'Hostname': 'restricted_zone_a_subnet_router',
#             'OSType': <OperatingSystemType.LINUX: 3>,
# ...

# %%
from CybORG.Simulator.Actions import Sleep

# %%
results = cyborg.step(agent="blue_agent_0", action=Sleep())
print(results.observation)
# Out:
# {'success': <TernaryEnum.UNKNOWN: 2>, 'action': Sleep}

# %%
for agent_name, ai in cyborg.environment_controller.agent_interfaces.items():
    if 'green' in agent_name and isinstance(ai.agent, EnterpriseGreenAgent):
        ai.agent.fp_detection_rate = 1.0

results = cyborg.step(agent="blue_agent_0", action=Sleep())
print(results.observation)
# Out:
# {
#     'success': <TernaryEnum.UNKNOWN: 2>,
#     'action': Sleep,
#     'restricted_zone_a_subnet_user_host_0': {
#         'Processes': [{'Connections': [{'local_port': 54850, 'local_address': IPv4Address('10.0.145.232')}]}],
#         'Interface': [{'ip_address': IPv4Address('10.0.145.232')}],
#         'System info': {
#             'Hostname': 'restricted_zone_a_subnet_user_host_0',
#             'OSType': <OperatingSystemType.LINUX: 3>,
#             'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#             'OSVersion': <OperatingSystemVersion.UNKNOWN: 1>,
#             'Architecture': <Architecture.x64: 2>,
#             'position': array([0., 0.])
#         }
#     },
#     'restricted_zone_a_subnet_user_host_2': {
#         'Processes': [{'Connections': [{'local_port': 51395, 'local_address': IPv4Address('10.0.145.228')}]}],
#         'Interface': [{'ip_address': IPv4Address('10.0.145.228')}],
#         'System info': {
# ...
